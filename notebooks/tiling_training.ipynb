# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/tiling-dataset3/tiling-dataset.zip /content/

# %%
# !unzip -q tiling-dataset.zip

# %%
# !mkdir /content/dataset

# %%
# %%writefile /content/dataset/data.yaml
# train: /content/content/tiling-dataset/train/images
# val: /content/content/tiling-dataset/val/images
# test: /content/content/tiling-dataset/test/images
#
# # Số lượng class
# nc: 1
#
# # Tên các class
# names: ['person']
# Out:
# Writing /content/dataset/data.yaml

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.2 MB/s eta 0:00:00

# %% [markdown]
# **START TRAINNING FOR THE FIRST TIME**

# %%
# !yolo detect train \
  data=/content/dataset/data.yaml \
  model=yolov8s.pt \
  epochs=50 \
  imgsz=640 \
  batch=32 \
  project=/content
# Out:
# Ultralytics 8.3.162 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp -R /content/train2 /content/drive/MyDrive/tiling-dataset3/

# %% [markdown]
# **RESUME TRAINING**

# %%
# !cp -R /content/drive/MyDrive/tiling-dataset3/train2 /content/

# %%
# !yolo detect train \
  model=/content/train2/weights/last.pt \
  data=/content/dataset/data.yaml \
  epochs=50 \
  batch=32 \
  imgsz=640 \
  project=/content \
  resume=True # IMPORTANT
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.162 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp -R /content/train2 /content/drive/MyDrive/tiling-dataset3/

# %% [markdown]
# **ĐÁNH GIÁ MÔ HÌNH**

# %%
# !yolo val model=/content/train2/weights/best.pt \
          data=/content/dataset/data.yaml \
          split=test \
          imgsz=640 \
          project=/content
# Out:
# Ultralytics 8.3.162 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 25.0±12.4 MB/s, size: 56.7 KB)
# val: Scanning /content/content/tiling-dataset/test/labels... 8762 images, 2110 backgrounds, 0 corrupt: 100% 8762/8762 [00:20<00:00, 432.57it/s]
# val: New cache created: /content/content/tiling-dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 548/548 [02:02<00:00,  4.48it/s]
#                    all       8762      93219      0.845      0.741      0.813      0.548
# Speed: 0.2ms preprocess, 9.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !cp -R /content/val /content/drive/MyDrive/tiling-dataset3/
